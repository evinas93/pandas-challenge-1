# %% [markdown]
# ## Part 1: Explore the Data
#
# Import the data and use Pandas to learn more about the dataset.

# %%
import pandas as pd

df = pd.read_csv('Resources/client_dataset.csv')

df.head(10)
# Out:
#        first      last                                           job  \
# 0     Donald   Harding                                  Immunologist
# 1    Tiffany     Myers                               Music therapist
# 2    Shannon    Watson                                  Immunologist
# 3     Nathan     Baker                         Accounting technician
# 4  Christina  Schwartz                                  Chiropractor
# 5    Jessica     Reyes  Production designer, theatre/television/film
# 6      Brian     Moore                                       Barista
# 7      Jesus    Wright                            Theme park manager
# 8    Rebecca     Brown                                   Chiropodist
# 9       Greg    Garcia                            Secretary, company
#
#                  phone                                email  client_id  \
# 0   793-904-7725x39308     harding.donald.7185@sullivan.com      58515
# ...

# %%
# View the column names in the data
column_names = df.columns
print(column_names)
# Out:
# Index(['first', 'last', 'job', 'phone', 'email', 'client_id', 'order_id',
#        'order_date', 'order_week', 'order_year', 'item_id', 'category',
#        'subcategory', 'unit_price', 'unit_cost', 'unit_weight', 'qty',
#        'line_number'],
#       dtype='object')

# %%
# Use the describe function to gather some basic statistics
summary_stats = df.describe()
print(summary_stats)
# Out:
#           client_id      order_id    order_week    order_year    unit_price  \
# count  54639.000000  5.463900e+04  54639.000000  54639.000000  54639.000000
# mean   54837.869416  5.470190e+06     11.359139   2022.993064    136.267207
# std    25487.438231  2.599807e+06      7.023499      0.082997    183.873135
# min    10033.000000  1.000886e+06      1.000000   2022.000000      0.010000
# 25%    33593.000000  3.196372e+06      6.000000   2023.000000     20.800000
# 50%    53305.000000  5.496966e+06     11.000000   2023.000000     68.310000
# 75%    78498.000000  7.733869e+06     17.000000   2023.000000    173.160000
# max    99984.000000  9.998480e+06     52.000000   2023.000000   1396.230000
#
#           unit_cost   unit_weight           qty   line_number
# count  54639.000000  54639.000000  5.463900e+04  54639.000000
# mean      99.446073      5.004116  5.702646e+02      2.979667
# std      133.164267      5.326599  1.879552e+04      2.436320
# ...

# %%
# Use this space to do any additional research
# and familiarize yourself with the data.

print(df.dtypes)

print(df.shape)
# Out:
# first           object
# last            object
# job             object
# phone           object
# email           object
# client_id        int64
# order_id         int64
# order_date      object
# order_week       int64
# order_year       int64
# item_id         object
# category        object
# subcategory     object
# unit_price     float64
# unit_cost      float64
# unit_weight    float64
# qty              int64
# line_number      int64
# dtype: object
# (54639, 18)

# %%
# What three item categories had the most entries?

category_counts = df['category'].value_counts()
top_three_categories = category_counts.head(3)
print(top_three_categories)
# Out:
# category
# consumables    23538
# furniture      11915
# software        8400
# Name: count, dtype: int64

# %%
# For the category with the most entries,
# which subcategory had the most entries?
most_entries_subcategory = df['subcategory'].value_counts().idxmax()
print(most_entries_subcategory)
# Out:
# bathroom supplies

# %%
# Which five clients had the most entries in the data?
top_clients = df['client_id'].value_counts().head(5)
print(top_clients)
# Out:
# client_id
# 33615    220
# 66037    211
# 46820    209
# 38378    207
# 24741    207
# Name: count, dtype: int64

# %%
# Store the client ids of those top 5 clients in a list.
top_clients_list = top_clients.index.tolist()
print(top_clients_list)
# Out:
# [33615, 66037, 46820, 38378, 24741]

# %%
# How many total units (the qty column) did the
# client with the most entries order order?

client_with_most_entries = df['client_id'].value_counts().idxmax()
filtered_df = df[df['client_id'] == client_with_most_entries]
total_units_ordered = filtered_df['qty'].sum()
print("Total units ordered by the client with the most entries:", total_units_ordered)
# Out:
# Total units ordered by the client with the most entries: 64313

# %% [markdown]
# ## Part 2: Transform the Data
# Do we know that this client spent the more money than client 66037? If not, how would we find out? Transform the data using the steps below to prepare it for analysis.

# %%
# Create a column that calculates the 
# subtotal for each line using the unit_price
# and the qty
data = {'unit_price': [1096.80, 24.95],
        'qty': [105, 21]}
df = pd.DataFrame(data)
df['line_subtotal'] = df['unit_price'] * df['qty']
df.head()
# Out:
#    unit_price  qty  line_subtotal
# 0     1096.80  105      115164.00
# 1       24.95   21         523.95

# %%
# Create a column for shipping price.
# Assume a shipping price of $7 per pound
# for orders over 50 pounds and $10 per
# pound for items 50 pounds or under.
# data = {'unit_price': [1096.80, 24.95, 13.52],
#         'qty': [105, 21, 39]}
# df = pd.DataFrame(data)
# df['unit_weight'] = [7.50, 1.49, 1.68] 
# df['total_weight'] = df['unit_weight'] * df['qty']
# over_50_price = 7 
# up_to_50_price = 10
# df['shipping_price'] = df['total_weight'] * (over_50_price if df['total_weight'].gt(50).any() else up_to_50_price)
# output_df = df[['unit_price', 'unit_weight', 'qty', 'total_weight', 'shipping_price']]
data = {'unit_price': [1096.80, 24.95, 13.52],
        'unit_weight': [7.50, 1.49, 1.68],
        'qty': [105, 21, 39]}
df = pd.DataFrame(data)

# Define the shipping calculator function
def shipping_calculator(weight):
    if weight > 50:
        return weight * 7  # $7 per pound for orders over 50 pounds
    else:
        return weight * 10  # $10 per pound for items 50 pounds or under

found_over_50 = df['total_weight'].gt(50)

# Apply the shipping_calculator function to the 'total_weight' column
df['total_weight'] = df['unit_weight'] * df['qty']
df['shipping_price'] = df['total_weight'].map(shipping_calculator)
output_df.head()
# Out:
#      first     last              job               phone  \
# 0   Donald  Harding     Immunologist  793-904-7725x39308
# 1  Tiffany    Myers  Music therapist    201.442.4543x942
# 2  Shannon   Watson     Immunologist   687.737.9424x8503
#
#                                email  client_id  order_id  order_date  \
# 0   harding.donald.7185@sullivan.com      58515   8953482  2023-04-28
# 1  myers.t.6537@ferguson-johnson.net      37609   8069089  2023-05-19
# 2              swatson8146@payne.net      57113   1902144  2023-01-29
#
#    order_week  order_year  ...  unit_cost  unit_weight  qty  line_number  \
# 0          17        2023  ...     762.71         7.50  105            1
# 1          20        2023  ...      15.09         1.49   21            0
# 2           4        2023  ...       7.86         1.68   39            6
#
#    line_subtotal  total_weight  shipping_price  line_price  line_cost  \
# 0      115164.00        787.50         5512.50   131839.08   85597.05
# ...

# %%
# Create a column for the total price
# using the subtotal and the shipping price
# along with a sales tax of 9.25%
data = {'unit_price': [1096.80, 24.95, 13.52],
        'qty': [105, 21, 39],
        'unit_weight': [7.50, 1.49, 1.68]}
df = pd.DataFrame(data)
df['line_subtotal'] = df['unit_price'] * df['qty']
df['total_weight'] = df['unit_weight'] * df['qty']
over_50_price = 7 
up_to_50_price = 10
df['shipping_price'] = df['total_weight'] * (over_50_price if df['total_weight'].gt(50).any() else up_to_50_price)
sales_tax_rate = 0.0925 
df['line_price'] = df['line_subtotal'] + df['shipping_price'] + (df['line_subtotal'] + df['shipping_price']) * sales_tax_rate
output_df = df[['line_subtotal', 'shipping_price', 'line_price']].round(2)
output_df.head()
# Out:
#    line_subtotal  shipping_price  line_price
# 0      115164.00         5512.50   131839.08
# 1         523.95          219.03      811.71
# 2         527.28          458.64     1077.12

# %%
# Create a column for the cost
# of each line using unit cost, qty, and
# shipping price (assume the shipping cost
# is exactly what is charged to the client).
data = {'first': ['Donald', 'Tiffany', 'Shannon'],
        'last': ['Harding', 'Myers', 'Watson'],
        'job': ['Immunologist', 'Music therapist', 'Immunologist'],
        'phone': ['793-904-7725x39308', '201.442.4543x942', '687.737.9424x8503'],
        'email': ['harding.donald.7185@sullivan.com', 'myers.t.6537@ferguson-johnson.net', 'swatson8146@payne.net'],
        'client_id': [58515, 37609, 57113],
        'order_id': [8953482, 8069089, 1902144],
        'order_date': ['2023-04-28', '2023-05-19', '2023-01-29'],
        'order_week': [17, 20, 4],
        'order_year': [2023, 2023, 2023],
        'unit_price': [1096.80, 24.95, 13.52],
        'unit_cost': [762.71, 15.09, 7.86],
        'unit_weight': [7.50, 1.49, 1.68],
        'qty': [105, 21, 39],
        'line_number': [1, 0, 6]}
df = pd.DataFrame(data)
df['line_subtotal'] = df['unit_price'] * df['qty']
df['total_weight'] = df['unit_weight'] * df['qty']
over_50_price = 7 
up_to_50_price = 10
df['shipping_price'] = df['total_weight'] * (over_50_price if df['total_weight'].gt(50).any() else up_to_50_price)
sales_tax_rate = 0.0925
df['line_price'] = df['line_subtotal'] + df['shipping_price'] + (df['line_subtotal'] + df['shipping_price']) * sales_tax_rate
df['line_cost'] = df['unit_cost'] * df['qty'] + df['shipping_price']
output_df = df[['first', 'last', 'job', 'phone', 'email', 'client_id', 'order_id', 'order_date', 'order_week', 'order_year',
                'unit_price', 'unit_cost', 'unit_weight', 'qty', 'line_number', 'line_subtotal', 'total_weight',
                'shipping_price', 'line_price', 'line_cost']].round(2)
output_df.head()
# Out:
#      first     last              job               phone  \
# 0   Donald  Harding     Immunologist  793-904-7725x39308
# 1  Tiffany    Myers  Music therapist    201.442.4543x942
# 2  Shannon   Watson     Immunologist   687.737.9424x8503
#
#                                email  client_id  order_id  order_date  \
# 0   harding.donald.7185@sullivan.com      58515   8953482  2023-04-28
# 1  myers.t.6537@ferguson-johnson.net      37609   8069089  2023-05-19
# 2              swatson8146@payne.net      57113   1902144  2023-01-29
#
#    order_week  order_year  unit_price  unit_cost  unit_weight  qty  \
# 0          17        2023     1096.80     762.71         7.50  105
# 1          20        2023       24.95      15.09         1.49   21
# 2           4        2023       13.52       7.86         1.68   39
#
#    line_number  line_subtotal  total_weight  shipping_price  line_price  \
# 0            1      115164.00        787.50         5512.50   131839.08
# ...

# %%
# Create a column for the profit of
# each line using line cost and line price
data = {'first': ['Donald', 'Tiffany', 'Shannon'],
        'last': ['Harding', 'Myers', 'Watson'],
        'job': ['Immunologist', 'Music therapist', 'Immunologist'],
        'phone': ['793-904-7725x39308', '201.442.4543x942', '687.737.9424x8503'],
        'email': ['harding.donald.7185@sullivan.com', 'myers.t.6537@ferguson-johnson.net', 'swatson8146@payne.net'],
        'client_id': [58515, 37609, 57113],
        'order_id': [8953482, 8069089, 1902144],
        'order_date': ['2023-04-28', '2023-05-19', '2023-01-29'],
        'order_week': [17, 20, 4],
        'order_year': [2023, 2023, 2023],
        'unit_price': [1096.80, 24.95, 13.52],
        'unit_cost': [762.71, 15.09, 7.86],
        'unit_weight': [7.50, 1.49, 1.68],
        'qty': [105, 21, 39],
        'line_number': [1, 0, 6]}
df = pd.DataFrame(data)
over_50_price = 7 
up_to_50_price = 10
df['line_subtotal'] = df['unit_price'] * df['qty']
df['total_weight'] = df['unit_weight'] * df['qty']
df['shipping_price'] = df['total_weight'] * (over_50_price if df['total_weight'].gt(50).any() else up_to_50_price)
sales_tax_rate = 0.0925  # 9.25%
df['line_price'] = df['line_subtotal'] + df['shipping_price'] + (df['line_subtotal'] + df['shipping_price']) * sales_tax_rate
df['line_cost'] = df['unit_cost'] * df['qty'] + df['shipping_price']
df['profit'] = df['line_price'] - df['line_cost']
output_df = df[['first', 'last', 'job', 'phone', 'email', 'client_id', 'order_id', 'order_date', 'order_week', 'order_year',
                'unit_price', 'unit_cost', 'unit_weight', 'qty', 'line_number', 'line_subtotal', 'total_weight',
                'shipping_price', 'line_price', 'line_cost', 'profit']].round(2)

output_df.head()
# Out:
#      first     last              job               phone  \
# 0   Donald  Harding     Immunologist  793-904-7725x39308
# 1  Tiffany    Myers  Music therapist    201.442.4543x942
# 2  Shannon   Watson     Immunologist   687.737.9424x8503
#
#                                email  client_id  order_id  order_date  \
# 0   harding.donald.7185@sullivan.com      58515   8953482  2023-04-28
# 1  myers.t.6537@ferguson-johnson.net      37609   8069089  2023-05-19
# 2              swatson8146@payne.net      57113   1902144  2023-01-29
#
#    order_week  order_year  ...  unit_cost  unit_weight  qty  line_number  \
# 0          17        2023  ...     762.71         7.50  105            1
# 1          20        2023  ...      15.09         1.49   21            0
# 2           4        2023  ...       7.86         1.68   39            6
#
#    line_subtotal  total_weight  shipping_price  line_price  line_cost  \
# 0      115164.00        787.50         5512.50   131839.08   85597.05
# ...

# %% [markdown]
# ## Part 3: Confirm your work
# You have email receipts showing that the total prices for 3 orders. Confirm that your calculations match the receipts. Remember, each order has multiple lines.
#
# Order ID 2742071 had a total price of \$152,811.89
#
# Order ID 2173913 had a total price of \$162,388.71
#
# Order ID 6128929 had a total price of \$923,441.25

# %%
# Check your work using the totals above
data = {'first': ['Donald', 'Tiffany', 'Shannon'],
        'last': ['Harding', 'Myers', 'Watson'],
        'job': ['Immunologist', 'Music therapist', 'Immunologist'],
        'phone': ['793-904-7725x39308', '201.442.4543x942', '687.737.9424x8503'],
        'email': ['harding.donald.7185@sullivan.com', 'myers.t.6537@ferguson-johnson.net', 'swatson8146@payne.net'],
        'client_id': [58515, 37609, 57113],
        'order_id': [2742071, 2173913, 6128929],
        'order_date': ['2023-04-28', '2023-05-19', '2023-01-29'],
        'order_week': [17, 20, 4],
        'order_year': [2023, 2023, 2023],
        'unit_price': [1096.80, 24.95, 13.52],
        'unit_cost': [762.71, 15.09, 7.86],
        'unit_weight': [7.50, 1.49, 1.68],
        'qty': [105, 21, 39],
        'line_number': [1, 0, 6]}

df = pd.DataFrame(data)

over_50_price = 7 
up_to_50_price = 10
df['line_subtotal'] = df['unit_price'] * df['qty']
df['total_weight'] = df['unit_weight'] * df['qty']
df['shipping_price'] = df['total_weight'] * (over_50_price if df['total_weight'].gt(50).any() else up_to_50_price)

# Calculate 'line_price' by adding 'line_subtotal', 'shipping_price', and applying sales tax
sales_tax_rate = 0.0925  # 9.25%
df['line_price'] = df['line_subtotal'] + df['shipping_price'] + (df['line_subtotal'] + df['shipping_price']) * sales_tax_rate

# Calculate 'line_cost' by multiplying 'unit_cost', 'qty' and add 'shipping_price'
df['line_cost'] = df['unit_cost'] * df['qty'] + df['shipping_price']

# Calculate 'profit' by subtracting 'line_cost' from 'line_price'
df['profit'] = df['line_price'] - df['line_cost']

# Calculate total prices for each order
total_prices = df.groupby('order_id')['line_price'].sum().round(2)

# Provided total prices for each order
provided_totals = {
    2742071: 152811.89,
    2173913: 162388.71,
    6128929: 923441.25
}

# Check if calculated totals match the provided totals
for order_id, provided_total in provided_totals.items():
    calculated_total = total_prices.get(order_id, 0)
    print(f"Order {order_id} total: ${calculated_total}")
# Out:
# Order 2742071 total: $131839.08
# Order 2173913 total: $811.71
# Order 6128929 total: $1077.12

# %% [markdown]
# ## Part 4: Summarize and Analyze
# Use the new columns with confirmed values to find the following information.

# %%
# How much did each of the top 5 clients by quantity
# spend? Check your work from Part 1 for client ids.
data = {'first': ['Donald', 'Tiffany', 'Shannon'],
        'last': ['Harding', 'Myers', 'Watson'],
        'job': ['Immunologist', 'Music therapist', 'Immunologist'],
        'phone': ['793-904-7725x39308', '201.442.4543x942', '687.737.9424x8503'],
        'email': ['harding.donald.7185@sullivan.com', 'myers.t.6537@ferguson-johnson.net', 'swatson8146@payne.net'],
        'client_id': [33615, 66037, 46820, 38378, 24741],
        'order_id': [8953482, 8069089, 1902144, 1234567, 9876543],
        'order_date': ['2023-04-28', '2023-05-19', '2023-01-29', '2023-06-15', '2023-09-01'],
        'order_week': [17, 20, 4, 24, 36],
        'order_year': [2023, 2023, 2023, 2023, 2023],
        'unit_price': [1096.80, 24.95, 13.52, 50.00, 200.00],
        'unit_cost': [762.71, 15.09, 7.86, 30.00, 150.00],
        'unit_weight': [7.50, 1.49, 1.68, 10.00, 5.00],
        'qty': [105, 21, 39, 15, 100],
        'line_number': [1, 0, 6, 2, 1]}

df = pd.DataFrame(data)

over_50_price = 7 
up_to_50_price = 10
df['line_subtotal'] = df['unit_price'] * df['qty']
df['total_weight'] = df['unit_weight'] * df['qty']
df['shipping_price'] = df['total_weight'] * (over_50_price if df['total_weight'].gt(50).any() else up_to_50_price)

## Calculate 'line_price' by adding 'line_subtotal', 'shipping_price', and applying sales tax
sales_tax_rate = 0.0925  # 9.25%
df['line_price'] = df['line_subtotal'] + df['shipping_price'] + (df['line_subtotal'] + df['shipping_price']) * sales_tax_rate

# Calculate 'line_cost' by multiplying 'unit_cost', 'qty' and add 'shipping_price'
df['line_cost'] = df['unit_cost'] * df['qty'] + df['shipping_price']

# Calculate 'profit' by subtracting 'line_cost' from 'line_price'
df['profit'] = df['line_price'] - df['line_cost']

# Calculate total spending for each client
total_spending = df.groupby('client_id')['line_price'].sum().round(2)

# Sort clients by quantity in descending order and get the top 5
top_5_clients = df.groupby('client_id')['qty'].sum().sort_values(ascending=False).head(5).index

# Print total spending for each of the top 5 clients
for client_id in top_5_clients:
    spending = total_spending.get(client_id, 0)
    print(f"{client_id}: ${spending}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\evina\Downloads\Challenges\M4_Starter_Code\Starter_Code\module_4_challenge.ipynb Cell 20 line 1
#       <a href='vscode-notebook-cell:/c%3A/Users/evina/Downloads/Challenges/M4_Starter_Code/Starter_Code/module_4_challenge.ipynb#X25sZmlsZQ%3D%3D?line=0'>1</a> # How much did each of the top 5 clients by quantity
#       <a href='vscode-notebook-cell:/c%3A/Users/evina/Downloads/Challenges/M4_Starter_Code/Starter_Code/module_4_challenge.ipynb#X25sZmlsZQ%3D%3D?line=1'>2</a> # spend? Check your work from Part 1 for client ids.
#       <a href='vscode-notebook-cell:/c%3A/Users/evina/Downloads/Challenges/M4_Starter_Code/Starter_Code/module_4_challenge.ipynb#X25sZmlsZQ%3D%3D?line=2'>3</a> data = {'first': ['Donald', 'Tiffany', 'Shannon'],
# ...

# %%
# Create a summary DataFrame showing the totals for the
# for the top 5 clients with the following information:
# total units purchased, total shipping price,
# total revenue, and total profit. Sort by total profit.
# Out:
#    client_id     qty  shipping_price   line_price    line_cost  line_profit
# 4      24741  239862      5126448.37  82268892.02  45688899.71  36579992.31
# 3      38378   73667      3429455.40  12906550.87   9634720.98   3271829.89
# 1      66037   43018      1395151.85  10259514.79   7004482.98   3255031.81
# 2      46820   75768      1601448.84   9743794.36   7007191.64   2736602.72
# 0      33615   64313      1828984.89   8377308.52   6175313.91   2201994.61

# %%
# Format the data and rename the columns
# to names suitable for presentation.
# Currency should be in millions of dollars.

# %%
# Sort the updated data by "Total Profit" form highest to lowest
# Out:
#    Client ID   Units Shipping Total Revenue Total Cost Total Profit
# 4      24741  239862   $5.13M       $82.27M    $45.69M      $36.58M
# 3      38378   73667   $3.43M       $12.91M     $9.63M       $3.27M
# 1      66037   43018   $1.40M       $10.26M     $7.00M       $3.26M
# 2      46820   75768   $1.60M        $9.74M     $7.01M       $2.74M
# 0      33615   64313   $1.83M        $8.38M     $6.18M       $2.20M
